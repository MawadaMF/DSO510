# %%
import pandas as pd

# %%
locations_df = pd.read_csv('https://raw.githubusercontent.com/MawadaMF/DSO510/main/universities_cleaned.csv?token=AWOHSXPJFWXLMCIKRGRITZDBR4PSC')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-81-af11ee55b51b> in <module>
# ----> 1 locations_df = pd.read_csv('https://raw.githubusercontent.com/MawadaMF/DSO510/main/universities_cleaned.csv?token=AWOHSXPJFWXLMCIKRGRITZDBR4PSC')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     556
#     557     # open URLs
# --> 558     ioargs = _get_filepath_or_buffer(
#     559         path_or_buf,
#     560         encoding=encoding,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     287                 "storage_options passed with file object or non-fsspec file path"
#     288             )
# --> 289         req = urlopen(filepath_or_buffer)
#     290         content_encoding = req.headers.get("Content-Encoding", None)
#     291         if content_encoding == "gzip":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     193     import urllib.request
#     194
# --> 195     return urllib.request.urlopen(*args, **kwargs)
#     196
#     197
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
locations_df.head()
# Out:
#                                     School_x business_school  Acceptance Rate  \
# 0       University of Pennsylvania (Wharton)         Wharton           0.0649
# 1  Washington University in St. Louis (Olin)            Olin           0.0970
# 2   University of California-Berkeley (Haas)            Haas           0.0430
# 3                 Cornell University (Dyson)           Dyson           0.0290
# 4              University of Michigan (Ross)            Ross           0.1200
#
#    Average Salary
# 0           80354
# 1           67115
# 2           73302
# 3           74493
# 4           72268

# %%
locations_df.to_csv('locations_uni.csv',index=False)

# %%
locs_dist['New_School_Cord'] = list(zip(locs_dist['School_Latitude'],locs_dist["School_Longitude"]))

# %%
locs_dist['New_City_Cord'] = list(zip(locs_dist['Nearest MTA_Lat'],locs_dist['Nearest MTA_Long']))

# %%
from geopy import distance

# %%
locs_dist['New_School_Cord']
# Out:
# 0     (39.95216943, -75.19346047)
# 1     (38.65127384, -90.31113952)
# 2     (37.87188001, -122.2585412)
# 3     (42.51049151, -76.48402902)
# 4     (42.27827145, -83.73789088)
#                  ...
# 83      (39.68071275, -75.755743)
# 84    (38.94256431, -92.32964577)
# 85     (38.6374555, -90.23585133)
# 86     (41.22058619, -73.2423947)
# 87    (40.43747921, -79.99371967)
# Name: New_School_Cord, Length: 88, dtype: object

# %%
locs_dist['Distance to Nearest City'] = locs_dist[['New_School_Cord','New_City_Cord']]\
.apply(lambda x: distance.distance(*x).miles,axis=1)

# %%
locs_dist.head()
# Out:
#                                     School_x business_school  Acceptance Rate  \
# 0       University of Pennsylvania (Wharton)         Wharton           0.0649
# 1  Washington University in St. Louis (Olin)            Olin           0.0970
# 2   University of California-Berkeley (Haas)            Haas           0.0430
# 3                 Cornell University (Dyson)           Dyson           0.0290
# 4              University of Michigan (Ross)            Ross           0.1200
#
#    Average Salary  School_Latitude  School_Longitude  Nearest MTA_Lat  \
# 0           80354        39.952169        -75.193460        39.952769
# 1           67115        38.651274        -90.311140        39.768689
# 2           73302        37.871880       -122.258541        37.769506
# 3           74493        42.510492        -76.484029        40.711833
# 4           72268        42.278271        -83.737891        42.331541
#
#    Nearest MTA_Long In the MTA?    City Chosen              New_School_Cord  \
# 0        -75.164078         Yes   Philadelphia  (39.95216943, -75.19346047)
# 1        -86.160549          No   Indianapolis  (38.65127384, -90.31113952)
# 2       -122.420162          No  San Francisco  (37.87188001, -122.2585412)
# 3        -74.006974          No       New York  (42.51049151, -76.48402902)
# 4        -83.045640          No        Detroit  (42.27827145, -83.73789088)
#
#                  New_City_Cord  Distance to Nearest City Far vs Close
# 0  (39.95276917, -75.16407793)                  1.560704        Close
# 1  (39.76868853, -86.16054897)                235.684726          Far
# 2  (37.76950648, -122.4201616)                 11.315188        Close
# 3   (40.71183265, -74.0069742)                178.500330          Far
# 4  (42.33154136, -83.04563958)                 35.657174        Close

# %%
locs_dist['Far vs Close']= ['Close' if i <=50 else 'Far' for i in locs_dist['Distance to Nearest City']]

# %%
locs_dist.sample(20)
# Out:
#                                              School_x      business_school  \
# 24                                     Babson College       Babson College
# 0                University of Pennsylvania (Wharton)              Wharton
# 53                     University of Oklahoma (Price)                Price
# 82         University of South Carolina (Darla Moore)          Darla Moore
# 54       Rochester Institute of Technology (Saunders)             Saunders
# 32     University of Massachusetts-Amherst (Isenberg)             Isenberg
# 23                  University of Minnesota (Carlson)              Carlson
# 40                       Purdue University (Krannert)             Krannert
# 41           Rensselaer Polytechnic Institute (Lally)                Lally
# 33                        University of Utah (Eccles)               Eccles
# 38                Texas Christian University (Neeley)               Neeley
# 77                    University of Michigan-Dearborn    Michigan-Dearborn
# 37                     University of Denver (Daniels)              Daniels
# 80                Brigham Young University (Marriott)             Marriott
# 68                     Christopher Newport University  Christopher Newport
# 64  University of Illinois at Champaign-Urbana (Geis)                 Gies
# 2            University of California-Berkeley (Haas)                 Haas
# 58                  Evansville University (Schroeder)            Schroeder
# 27                      University of Georgia (Terry)                Terry
# 31                      Syracuse University (Whitman)              Whitman
#
#     Acceptance Rate  Average Salary  School_Latitude  School_Longitude  \
# 24           0.2400           57665        42.296449        -71.265692
# 0            0.0649           80354        39.952169        -75.193460
# 53           0.6177           53134        35.207978        -97.443854
# 82           0.6510           61946        33.994470        -81.033315
# 54           0.7210           51273        43.082932        -77.677224
# 32           0.3060           57782        42.386831        -72.530159
# 23           0.2844           56989        44.970646        -93.245000
# 40           0.6200           57473        40.423724        -86.910822
# 41           0.4200           67200        42.731184        -73.683262
# 33           0.4080           51478        40.761763       -111.843554
# 38           0.4656           60719        32.709026        -97.357155
# 77           0.6200           49507        42.317706        -83.232030
# 37           0.4630           50975        39.676749       -104.961918
# 80           0.6316           55148        40.250493       -111.652565
# 68           0.7460           48000        37.064262        -76.493571
# 64           0.4898           63079        40.103745        -88.230544
# 2            0.0430           73302        37.871880       -122.258541
# 58           0.8860           50537        37.973317        -87.531875
# 27           0.4744           56428        33.948075        -83.377304
# 31           0.3810           59371        43.039185        -76.135255
#
#     Nearest MTA_Lat  Nearest MTA_Long In the MTA?    City Chosen  \
# 24        42.359798        -71.057226          No         Boston
# 0         39.952769        -75.164078         Yes   Philadelphia
# 53        35.466829        -97.516963          No  Oklahoma City
# 82        35.226742        -80.843877          No      Charlotee
# 54        40.711833        -74.006974          No       New York
# 32        42.359798        -71.057226          No         Boston
# 23        44.977555        -93.265413         Yes    Minneapolis
# 40        39.768689        -86.160549          No   Indianapolis
# 41        40.711833        -74.006974          No       New York
# 33        36.170015       -115.140659          No      Las Vegas
# 38        32.755709        -97.329946         Yes     Fort Worth
# 77        42.331541        -83.045640          No        Detroit
# 37        39.739429       -104.993971         Yes         Denver
# 80        36.170015       -115.140659          No      Las Vegas
# 68        38.907266        -77.037729          No  Washington DC
# 64        39.768689        -86.160549          No   Indianapolis
# 2         37.769506       -122.420162          No  San Francisco
# 58        38.252423        -85.758340          No     Louisville
# 27        33.748660        -84.388081          No        Atlanta
# 31        40.711833        -74.006974          No       New York
#
#                 New_School_Cord                New_City_Cord  \
# 24  (42.29644875, -71.26569158)   (42.35979786, -71.0572255)
# 0   (39.95216943, -75.19346047)  (39.95276917, -75.16407793)
# 53  (35.20797794, -97.44385362)  (35.46682917, -97.51696322)
# 82  (33.99446975, -81.03331476)   (35.2267415, -80.84387748)
# 54    (43.08293249, -77.677224)   (40.71183265, -74.0069742)
# 32   (42.3868311, -72.53015879)   (42.35979786, -71.0572255)
# 23  (44.97064555, -93.24499991)  (44.97755544, -93.26541254)
# 40  (40.42372377, -86.91082191)  (39.76868853, -86.16054897)
# 41    (42.7311836, -73.6832619)   (40.71183265, -74.0069742)
# 33  (40.76176301, -111.8435545)  (36.17001541, -115.1406592)
# 38  (32.70902562, -97.35715549)  (32.75570863, -97.32994566)
# 77   (42.31770568, -83.2320299)  (42.33154136, -83.04563958)
# 37    (39.6767495, -104.961918)  (39.73942856, -104.9939711)
# 80  (40.25049331, -111.6525646)  (36.17001541, -115.1406592)
# 68   (37.0642616, -76.49357092)  (38.90726615, -77.03772879)
# 64  (40.10374539, -88.23054399)  (39.76868853, -86.16054897)
# 2   (37.87188001, -122.2585412)  (37.76950648, -122.4201616)
# 58  (37.97331718, -87.53187513)  (38.25242321, -85.75834006)
# 27  (33.94807487, -83.37730435)  (33.74865951, -84.38808142)
# 31  (43.03918475, -76.13525528)   (40.71183265, -74.0069742)
#
#     Distance to Nearest City Far vs Close
# 24                 11.537386        Close
# 0                   1.560704        Close
# 53                 18.316652        Close
# 82                 85.624863          Far
# 54                250.145863          Far
# 32                 75.405513          Far
# 23                  1.108483        Close
# 40                 60.190221          Far
# 41                140.365403          Far
# 33                363.630499          Far
# 38                  3.586110        Close
# 77                  9.594292        Close
# 37                  4.649338        Close
# 80                339.402553          Far
# 68                130.535479          Far
# 64                112.339879          Far
# 2                  11.315188        Close
# 58                 98.541743          Far
# 27                 59.729321          Far
# 31                194.539676          Far

# %%
locs_dist.sample(20)
# Out:
#                                           School_x            business_school  \
# 53                  University of Oklahoma (Price)                      Price
# 28                   University of Houston (Bauer)                      Bauer
# 27                   University of Georgia (Terry)                      Terry
# 80             Brigham Young University (Marriott)                   Marriott
# 40                    Purdue University (Krannert)                   Krannert
# 81                       The College of New Jersey                       TCNJ
# 73                             Lipscomb University                   Lipscomb
# 1        Washington University in St. Louis (Olin)                       Olin
# 12             Southern Methodist University (Cox)                        Cox
# 32  University of Massachusetts-Amherst (Isenberg)                   Isenberg
# 0             University of Pennsylvania (Wharton)                    Wharton
# 47             University of Texas-Dallas (Jindal)                     Jindal
# 31                   Syracuse University (Whitman)                    Whitman
# 50                    St. Thomas University (Opus)                       Opus
# 18                     Indiana University (Kelley)                     Kelley
# 74         University of North Carolina-Wilmington  North Carolina-Wilmington
# 67                         University of San Diego                  San Diego
# 79                             University of Miami                      Miami
# 20           The College of William & Mary (Mason)                      Mason
# 49      University of Tennessee-Knoxville (Haslam)                     Haslam
#
#     Acceptance Rate  Average Salary  School_Latitude  School_Longitude  \
# 53           0.6177           53134        35.207978        -97.443854
# 28           0.2518           54144        29.721618        -95.338341
# 27           0.4744           56428        33.948075        -83.377304
# 80           0.6316           55148        40.250493       -111.652565
# 40           0.6200           57473        40.423724        -86.910822
# 81           0.4100           58000        40.268464        -74.777675
# 73           0.6100           46875        36.104686        -86.798916
# 1            0.0970           67115        38.651274        -90.311140
# 12           0.1112           67138        32.842323        -96.783638
# 32           0.3060           57782        42.386831        -72.530159
# 0            0.0649           80354        39.952169        -75.193460
# 47           0.6000           58100        32.985151        -96.746869
# 31           0.3810           59371        43.039185        -76.135255
# 50           0.8300           48000        44.974109        -93.277575
# 18           0.4038           62734        39.172537        -86.519337
# 74           0.6100           44507        34.223918        -77.869593
# 67           0.5300           57119        32.771910       -117.188331
# 79           0.3044           60801        25.717902        -80.274648
# 20           0.2240           64724        37.271802        -76.716091
# 49           0.8500           50446        35.955609        -83.928912
#
#     Nearest MTA_Lat  Nearest MTA_Long In the MTA?    City Chosen  \
# 53        35.466829        -97.516963          No  Oklahoma City
# 28        29.759497        -95.369147         Yes        Houston
# 27        33.748660        -84.388081          No        Atlanta
# 80        36.170015       -115.140659          No      Las Vegas
# 40        39.768689        -86.160549          No   Indianapolis
# 81        39.952769        -75.164078          No   Philadelphia
# 73        36.161945        -86.782198         Yes      Nashville
# 1         39.768689        -86.160549          No   Indianapolis
# 12        32.776570        -96.800336         Yes         Dallas
# 32        42.359798        -71.057226          No         Boston
# 0         39.952769        -75.164078         Yes   Philadelphia
# 47        32.776629        -96.799020          No         Dallas
# 31        40.711833        -74.006974          No       New York
# 50        44.977555        -93.265413         Yes    Minneapolis
# 18        39.768689        -86.160549          No   Indianapolis
# 74        35.226742        -80.843877          No      Charlotte
# 67        32.715229       -117.162203         Yes      San Diego
# 79        30.331659        -81.655630          No   Jacksonville
# 20        38.908131        -77.037291          No  Washington DC
# 49        36.161945        -86.782198          No      Nashville
#
#                 New_School_Cord                New_City_Cord  \
# 53  (35.20797794, -97.44385362)  (35.46682917, -97.51696322)
# 28  (29.72161771, -95.33834057)  (29.75949676, -95.36914678)
# 27  (33.94807487, -83.37730435)  (33.74865951, -84.38808142)
# 80  (40.25049331, -111.6525646)  (36.17001541, -115.1406592)
# 40  (40.42372377, -86.91082191)  (39.76868853, -86.16054897)
# 81  (40.26846354, -74.77767454)  (39.95276917, -75.16407793)
# 73  (36.10468642, -86.79891572)  (36.16194472, -86.78219784)
# 1   (38.65127384, -90.31113952)  (39.76868853, -86.16054897)
# 12  (32.84232309, -96.78363772)  (32.77656964, -96.80033616)
# 32   (42.3868311, -72.53015879)   (42.35979786, -71.0572255)
# 0   (39.95216943, -75.19346047)  (39.95276917, -75.16407793)
# 47  (32.98515098, -96.74686874)   (32.77662902, -96.7990196)
# 31  (43.03918475, -76.13525528)   (40.71183265, -74.0069742)
# 50  (44.97410853, -93.27757489)  (44.97755544, -93.26541254)
# 18  (39.17253714, -86.51933744)  (39.76868853, -86.16054897)
# 74  (34.22391834, -77.86959287)   (35.2267415, -80.84387748)
# 67   (32.77191006, -117.188331)  (32.71522851, -117.1622033)
# 79  (25.71790205, -80.27464753)  (30.33165916, -81.65563011)
# 20  (37.27180163, -76.71609132)   (38.9081312, -77.03729142)
# 49    (35.95560866, -83.928912)  (36.16194472, -86.78219784)
#
#     Distance to Nearest City Far vs Close
# 53                 18.316652        Close
# 28                  3.199365        Close
# 27                 59.729321          Far
# 80                339.402553          Far
# 40                 60.190221          Far
# 81                 29.890491        Close
# 73                  4.057081        Close
# 1                 235.684726          Far
# 12                  4.634147        Close
# 32                 75.405513          Far
# 0                   1.560704        Close
# 47                 14.686046        Close
# 31                194.539676          Far
# 50                  0.641885        Close
# 18                 45.381050        Close
# 74                182.834757          Far
# 67                  4.191835        Close
# 79                328.710307          Far
# 20                114.209191          Far
# 49                160.363306          Far

# %%
locs_dist.head()
# Out:
#                                     School_x business_school  Acceptance Rate  \
# 0       University of Pennsylvania (Wharton)         Wharton           0.0649
# 1  Washington University in St. Louis (Olin)            Olin           0.0970
# 2   University of California-Berkeley (Haas)            Haas           0.0430
# 3                 Cornell University (Dyson)           Dyson           0.0290
# 4              University of Michigan (Ross)            Ross           0.1200
#
#    Average Salary  School_Latitude  School_Longitude  Nearest MTA_Lat  \
# 0           80354        39.952169        -75.193460        39.952769
# 1           67115        38.651274        -90.311140        39.768689
# 2           73302        37.871880       -122.258541        37.769506
# 3           74493        42.510492        -76.484029        40.711833
# 4           72268        42.278271        -83.737891        42.331541
#
#    Nearest MTA_Long In the MTA?    City Chosen              New_School_Cord  \
# 0        -75.164078         Yes   Philadelphia  (39.95216943, -75.19346047)
# 1        -86.160549          No   Indianapolis  (38.65127384, -90.31113952)
# 2       -122.420162          No  San Francisco  (37.87188001, -122.2585412)
# 3        -74.006974          No       New York  (42.51049151, -76.48402902)
# 4        -83.045640          No        Detroit  (42.27827145, -83.73789088)
#
#                  New_City_Cord
# 0  (39.95276917, -75.16407793)
# 1  (39.76868853, -86.16054897)
# 2  (37.76950648, -122.4201616)
# 3   (40.71183265, -74.0069742)
# 4  (42.33154136, -83.04563958)

# %%
locs_dist = pd.read_csv('locations_uni.csv')
locs_dist
# Out:
#                                       School_x business_school  \
# 0         University of Pennsylvania (Wharton)         Wharton
# 1    Washington University in St. Louis (Olin)            Olin
# 2     University of California-Berkeley (Haas)            Haas
# 3                   Cornell University (Dyson)           Dyson
# 4                University of Michigan (Ross)            Ross
# ..                                         ...             ...
# 83             University of Delaware (Lerner)          Lerner
# 84  University of Missouri-Columbia (Trulaske)        Trulaske
# 85             St. Louis University (Chaifetz)        Chaifetz
# 86        Sacred Heart University (Jack Welch)      Jack Welch
# 87       Duquesne University (Palumbo Donahue)         Donahue
#
#     Acceptance Rate  Average Salary  School_Latitude  School_Longitude  \
# 0            0.0649           80354        39.952169        -75.193460
# 1            0.0970           67115        38.651274        -90.311140
# 2            0.0430           73302        37.871880       -122.258541
# 3            0.0290           74493        42.510492        -76.484029
# 4            0.1200           72268        42.278271        -83.737891
# ..              ...             ...              ...               ...
# 83           0.4640           54087        39.680713        -75.755743
# 84           0.6917           48827        38.942564        -92.329646
# 85           0.8303           63333        38.637456        -90.235851
# 86           0.6080           54784        41.220586        -73.242395
# 87           0.7600           50592        40.437479        -79.993720
#
#     Nearest MTA_Lat  Nearest MTA_Long In the MTA?    City Chosen
# 0         39.952769        -75.164078         Yes   Philadelphia
# 1         39.768689        -86.160549          No   Indianapolis
# 2         37.769506       -122.420162          No  San Francisco
# 3         40.711833        -74.006974          No       New York
# 4         42.331541        -83.045640          No        Detroit
# ..              ...               ...         ...            ...
# 83        39.952769        -75.164078          No   Philadelphia
# 84        39.768689        -86.160549          No   Indianapolis
# 85        39.768689        -86.160549          No   Indianapolis
# 86        40.711833        -74.006974          No       New York
# 87        39.952769        -75.164078          No   Philadelphia
#
# [88 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
locs_dist.sample()
# Out:
#                        School_x business_school  Acceptance Rate  \
# 13  Emory University (Goizueta)        Goizueta           0.1721
#
#     Average Salary  School_Latitude  School_Longitude  Nearest MTA_Lat  \
# 13           66297        33.797212        -84.322296         33.74866
#
#     Nearest MTA_Long In the MTA? City Chosen              New_School_Cord  \
# 13        -84.388081         Yes     Atlanta  (33.79721202, -84.32229567)
#
#                   New_City_Cord  Distance to Nearest City Far vs Close
# 13  (33.74865951, -84.38808142)                  5.053227        Close

# %%
locs_dist['Distance to Nearest City'].max()
# Out:
# 363.6304989714836

# %%
max_distance = locs_dist["Distance to Nearest City"].max()
#min_ROA
locs_dist.loc[locs_dist['Distance to Nearest City']== max_distance, ['School_x','Distance to Nearest City','City Chosen','Nearest MTA_Lat','Nearest MTA_Long']]
# Out:
#                        School_x  Distance to Nearest City City Chosen  \
# 33  University of Utah (Eccles)                363.630499   Las Vegas
#
#     Nearest MTA_Lat  Nearest MTA_Long
# 33        36.170015       -115.140659

# %%
locs_dist.loc[62,'Nearest MTA_Long']= -87.908132

# %%
locs_dist.iloc[62]
# Out:
# School_x                    University of Wisconsin-Madison
# business_school                                   Wisconsin
# Acceptance Rate                                        0.35
# Average Salary                                        58603
# School_Latitude                                   43.072622
# School_Longitude                                  -89.40139
# Nearest MTA_Lat                                   43.037596
# Nearest MTA_Long                                 -87.908132
# In the MTA?                                              No
# City Chosen                                       Milwaukee
# New_School_Cord                    (43.07262238, -89.40139)
# New_City_Cord                    (43.03759575, 87.90813192)
# Distance to Nearest City                        6501.085682
# Far vs Close                                            Far
# Name: 62, dtype: object

# %%
locs_dist.iloc[62]
# Out:
# School_x                    University of Wisconsin-Madison
# business_school                                   Wisconsin
# Acceptance Rate                                        0.35
# Average Salary                                        58603
# School_Latitude                                   43.072622
# School_Longitude                                  -89.40139
# Nearest MTA_Lat                                   43.037596
# Nearest MTA_Long                                 -87.908132
# In the MTA?                                              No
# City Chosen                                       Milwaukee
# New_School_Cord                    (43.07262238, -89.40139)
# New_City_Cord                    (43.03759575, 87.90813192)
# Distance to Nearest City                        6501.085682
# Far vs Close                                            Far
# Name: 62, dtype: object

# %%
sns.scatterplot(data=locs_dist,y=locs_dist['Distance to Nearest City'],x='Acceptance Rate',hue='Far vs Close')
tickposition = [0,25,50,75,100,125,150,175,200,225,250,275,300,325,350,375,400]
ticklabels = [0,25,50,75,100,125,150,175,200,225,250,275,300,325,350,375,400]
#plt.xticks(tickposition,ticklabels)

# %%
sns.scatterplot(data=locs_dist,x='Far vs Close',y='Acceptance Rate',hue='Far vs Close')
# Out:
# <AxesSubplot:xlabel='Far vs Close', ylabel='Acceptance Rate'>

# %%
sns.barplot(data=locs_dist,x='Far vs Close',y='Acceptance Rate',hue='Far vs Close')
# Out:
# <AxesSubplot:xlabel='Far vs Close', ylabel='Acceptance Rate'>

# %%
locs_dist.head(1)
# Out:
#                                School_x business_school  Acceptance Rate  \
# 0  University of Pennsylvania (Wharton)         Wharton           0.0649
#
#    Average Salary  School_Latitude  School_Longitude  Nearest MTA_Lat  \
# 0           80354        39.952169         -75.19346        39.952769
#
#    Nearest MTA_Long In the MTA?   City Chosen              New_School_Cord  \
# 0        -75.164078         Yes  Philadelphia  (39.95216943, -75.19346047)
#
#                  New_City_Cord  Distance to Nearest City Far vs Close
# 0  (39.95276917, -75.16407793)                  1.560704        Close

# %%
uni_cleaned = locs_dist[['School_x','business_school','Acceptance Rate','Average Salary','Distance to Nearest City','Far vs Close']]

# %%
uni_cleaned.head()
# Out:
#                                     School_x business_school  Acceptance Rate  \
# 0       University of Pennsylvania (Wharton)         Wharton           0.0649
# 1  Washington University in St. Louis (Olin)            Olin           0.0970
# 2   University of California-Berkeley (Haas)            Haas           0.0430
# 3                 Cornell University (Dyson)           Dyson           0.0290
# 4              University of Michigan (Ross)            Ross           0.1200
#
#    Average Salary  Distance to Nearest City Far vs Close
# 0           80354                  1.560704        Close
# 1           67115                235.684726          Far
# 2           73302                 11.315188        Close
# 3           74493                178.500330          Far
# 4           72268                 35.657174        Close

# %%
uni_cleaned.to_csv('universities_locations.csv')
