# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as sm

# %%
#read the data
data=pd.read_csv('universities_cleaned.csv')
data
# Out:
#     Unnamed: 0                                    School_x business_school  \
# 0            0        University of Pennsylvania (Wharton)         Wharton
# 1            1   Washington University in St. Louis (Olin)            Olin
# 2            2    University of California-Berkeley (Haas)            Haas
# 3            3                  Cornell University (Dyson)           Dyson
# 4            4               University of Michigan (Ross)            Ross
# ..         ...                                         ...             ...
# 83          83  University of South Carolina (Darla Moore)     Darla Moore
# 84          84             University of Delaware (Lerner)          Lerner
# 85          85  University of Missouri-Columbia (Trulaske)        Trulaske
# 86          86             St. Louis University (Chaifetz)        Chaifetz
# 87          87        Sacred Heart University (Jack Welch)      Jack Welch
#
#     Acceptance Rate  Average Salary  Public(0) or Private(1)  \
# 0            0.0649           80354                        1
# 1            0.0970           67115                        1
# 2            0.0430           73302                        0
# 3            0.0290           74493                        1
# 4            0.1200           72268                        0
# ..              ...             ...                      ...
# 83           0.6510           61946                        0
# 84           0.4640           54087                        0
# 85           0.6917           48827                        0
# 86           0.8303           63333                        1
# 87           0.6080           54784                        1
#
#     Reputation Score   Alumni  Tuition_Fees_17&18  \
# 0                4.8  99000.0             53534.0
# 1                4.1  21000.0             51533.0
# 2                4.6  39000.0             42184.0
# 3                4.3      NaN             52853.0
# 4                4.6  52000.0             32451.5
# ..               ...      ...                 ...
# 83               3.6  48000.0             23155.0
# 84               NaN  34400.0             18146.5
# 85               3.2  32000.0             42166.0
# 86               NaN  25625.0             39820.0
# 87               NaN      NaN             36394.0
#
#     Distance to Nearest City (Miles) Distance Far vs. Close
# 0                           1.560704                  Close
# 1                         235.684726                    Far
# 2                          11.315188                  Close
# 3                         178.500330                    Far
# 4                          35.657174                  Close
# ..                               ...                    ...
# 83                         36.649280                  Close
# 84                        335.203680                    Far
# 85                        232.209889                    Far
# 86                         53.214610                    Far
# 87                        257.681562                    Far
#
# [88 rows x 11 columns]

# %%
#distribution of alumni size
sns.histplot(data.Alumni)
# Out:
# <AxesSubplot:xlabel='Alumni', ylabel='Count'>

# %% [markdown]
# - we have high outliers

# %%
#number of universities with no value
data.Alumni.isna().sum()
# Out:
# 21

# %%
fig, ax= plt.subplots(2,1, figsize=(8,8))

sns.scatterplot(x=data['Acceptance Rate'], y=data['Alumni'], ax=ax[0])
sns.scatterplot(x=data['Average Salary'], y=data['Alumni'], ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Average Salary', ylabel='Alumni'>

# %% [markdown]
# - doesn't seem to be a relationship between alumni size and acceptance rate or average salary

# %%
data.sort_values(by='Alumni', ascending=False).head()
# Out:
#     Unnamed: 0                         School_x    business_school  \
# 77          77  University of Michigan-Dearborn  Michigan-Dearborn
# 39          39  University of Kentucky (Gatton)             Gatton
# 26          26     Fordham University (Gabelli)            Gabelli
# 43          43  Santa Clara University (Leavey)             Leavey
# 59          59             Villanova University          Villanova
#
#     Acceptance Rate  Average Salary  Public(0) or Private(1)  \
# 77           0.6200           49507                        0
# 39           0.6979           49175                        0
# 26           0.4490           63777                        1
# 43           0.4350           59333                        1
# 59           0.2207           63709                        1
#
#     Reputation Score    Alumni  Tuition_Fees_17&18  \
# 77               NaN  575000.0             18754.0
# 39               3.3  300000.0             19994.0
# 26               3.3  180000.0             50601.0
# 43               3.3  140000.0             49858.0
# 59               3.4  130000.0             51284.0
#
#     Distance to Nearest City (Miles) Distance Far vs. Close
# 77                          9.594292                  Close
# 39                         69.752142                    Far
# 26                         12.157420                  Close
# 43                          2.945132                  Close
# 59                         11.107455                  Close

# %%
#drop outliers
d=data.drop([77, 39])

# %%
fig, ax= plt.subplots(2,1, figsize=(8,8))

sns.scatterplot(x=d['Acceptance Rate'], y=d['Alumni'], hue=d['Public(0) or Private(1)'], ax=ax[0])
sns.scatterplot(x=d['Average Salary'], y=d['Alumni'], hue=d['Public(0) or Private(1)'], ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Average Salary', ylabel='Alumni'>

# %% [markdown]
# - doesn't seem to be a pattern between alumni size or type of school (public/private)

# %%
#replace empty results for Alumni with zero
d['Alumni']=d['Alumni'].fillna(0)
d.head()
# Out:
#    Unnamed: 0                                   School_x business_school  \
# 0           0       University of Pennsylvania (Wharton)         Wharton
# 1           1  Washington University in St. Louis (Olin)            Olin
# 2           2   University of California-Berkeley (Haas)            Haas
# 3           3                 Cornell University (Dyson)           Dyson
# 4           4              University of Michigan (Ross)            Ross
#
#    Acceptance Rate  Average Salary  Public(0) or Private(1)  Reputation Score  \
# 0           0.0649           80354                        1               4.8
# 1           0.0970           67115                        1               4.1
# 2           0.0430           73302                        0               4.6
# 3           0.0290           74493                        1               4.3
# 4           0.1200           72268                        0               4.6
#
#     Alumni  Tuition_Fees_17&18  Distance to Nearest City (Miles)  \
# 0  99000.0             53534.0                          1.560704
# 1  21000.0             51533.0                        235.684726
# 2  39000.0             42184.0                         11.315188
# 3      0.0             52853.0                        178.500330
# 4  52000.0             32451.5                         35.657174
#
#   Distance Far vs. Close
# 0                  Close
# 1                    Far
# 2                  Close
# 3                    Far
# 4                  Close

# %%
fig, ax= plt.subplots(2,1, figsize=(8,8))

# get coeffs of linear fit
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(d['Acceptance Rate'],d['Alumni'])
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(d['Average Salary'],d['Alumni'])


# use line_kws to set line label for legend
ax1 = sns.regplot(x="Acceptance Rate", y="Alumni", data=d, color='b', 
 line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope1,intercept1)}, ax=ax[0])

ax2 = sns.regplot(x="Average Salary", y="Alumni", data=d, color='b', 
 line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope2,intercept2)}, ax=ax[1])

# plot legend
ax1.legend()
ax2.legend()

plt.show()

# %%
#drop universities with empty alumni size
data = pd.read_csv('universities_cleaned.csv')
dd = data.drop([77, 39])
dd = dd[dd['Alumni'].notna()]
dd.head()
# Out:
#    Unnamed: 0                                   School_x business_school  \
# 0           0       University of Pennsylvania (Wharton)         Wharton
# 1           1  Washington University in St. Louis (Olin)            Olin
# 2           2   University of California-Berkeley (Haas)            Haas
# 4           4              University of Michigan (Ross)            Ross
# 5           5                New York University (Stern)           Stern
#
#    Acceptance Rate  Average Salary  Public(0) or Private(1)  Reputation Score  \
# 0           0.0649           80354                        1               4.8
# 1           0.0970           67115                        1               4.1
# 2           0.0430           73302                        0               4.6
# 4           0.1200           72268                        0               4.6
# 5           0.0800           80546                        1               4.4
#
#     Alumni  Tuition_Fees_17&18  Distance to Nearest City (Miles)  \
# 0  99000.0             53534.0                          1.560704
# 1  21000.0             51533.0                        235.684726
# 2  39000.0             42184.0                         11.315188
# 4  52000.0             32451.5                         35.657174
# 5  48000.0             50464.0                          1.326962
#
#   Distance Far vs. Close
# 0                  Close
# 1                    Far
# 2                  Close
# 4                  Close
# 5                  Close

# %%
fig, ax= plt.subplots(2,1, figsize=(8,8))

# get coeffs of linear fit
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(dd['Acceptance Rate'],dd['Alumni'])
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(dd['Average Salary'],dd['Alumni'])


# use line_kws to set line label for legend
ax1 = sns.regplot(x="Acceptance Rate", y="Alumni", data=dd, color='b', 
 line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope1,intercept1)}, ax=ax[0])

ax2 = sns.regplot(x="Average Salary", y="Alumni", data=dd, color='b', 
 line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope2,intercept2)}, ax=ax[1])

# plot legend
ax1.legend()
ax2.legend()

plt.show()

# %% [markdown]
# ## Regression

# %%
data=data.rename(columns={
    'Average Salary':'Salary','Acceptance Rate':'Acceptance',  'Public(0) or Private(1)':'Private',
    'Reputation Score':'Reputation','Tuition_Fees_17&18':'Tuition','Distance to Nearest City (Miles)':'Distance',
    'Distance Far vs. Close':'Far'})
d=d.rename(columns={
    'Average Salary':'Salary','Acceptance Rate':'Acceptance',  'Public(0) or Private(1)':'Private',
    'Reputation Score':'Reputation','Tuition_Fees_17&18':'Tuition','Distance to Nearest City (Miles)':'Distance',
    'Distance Far vs. Close':'Far'})
dd=dd.rename(columns={
    'Average Salary':'Salary','Acceptance Rate':'Acceptance',  'Public(0) or Private(1)':'Private',
    'Reputation Score':'Reputation','Tuition_Fees_17&18':'Tuition','Distance to Nearest City (Miles)':'Distance',
    'Distance Far vs. Close':'Far'})

# %%
#relationship between average salary and acceptance rate
result = sm.ols(formula="Salary ~ Acceptance", 
                data=data).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.530
# Method:                 Least Squares   F-statistic:                     99.28
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           5.39e-16
# Time:                        22:05:43   Log-Likelihood:                -886.87
# No. Observations:                  88   AIC:                             1778.
# Df Residuals:                      86   BIC:                             1783.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.085e+04   1349.317     52.507      0.000    6.82e+04    7.35e+04
# Acceptance -2.731e+04   2740.872     -9.964      0.000   -3.28e+04   -2.19e+04
# ==============================================================================
# Omnibus:                       10.802   Durbin-Watson:                   1.504
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               16.766
# Skew:                          -0.488   Prob(JB):                     0.000229
# Kurtosis:                       4.903   Cond. No.                         5.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#relationship between average salary and acceptance rate (empty alumni size replaced with zero)
result = sm.ols(formula="Salary ~ Acceptance", 
                data=d).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     90.91
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           7.77e-14
# Time:                        22:06:27   Log-Likelihood:                -647.17
# No. Observations:                  65   AIC:                             1298.
# Df Residuals:                      63   BIC:                             1303.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.175e+04   1351.781     53.079      0.000     6.9e+04    7.45e+04
# Acceptance -2.771e+04   2906.714     -9.535      0.000   -3.35e+04   -2.19e+04
# ==============================================================================
# Omnibus:                        2.655   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.265   Jarque-Bera (JB):                2.149
# Skew:                           0.444   Prob(JB):                        0.341
# Kurtosis:                       3.079   Cond. No.                         5.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#relationship between average salary and acceptance rate (universities with empty alumni size dropped)
result = sm.ols(formula="Salary ~ Acceptance", 
                data=dd).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     90.91
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           7.77e-14
# Time:                        22:06:15   Log-Likelihood:                -647.17
# No. Observations:                  65   AIC:                             1298.
# Df Residuals:                      63   BIC:                             1303.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.175e+04   1351.781     53.079      0.000     6.9e+04    7.45e+04
# Acceptance -2.771e+04   2906.714     -9.535      0.000   -3.35e+04   -2.19e+04
# ==============================================================================
# Omnibus:                        2.655   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.265   Jarque-Bera (JB):                2.149
# Skew:                           0.444   Prob(JB):                        0.341
# Kurtosis:                       3.079   Cond. No.                         5.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#relationship between average salary and acceptance rate controlling alumni size
result = sm.ols(formula="Salary ~ Acceptance + Alumni", 
                data=data).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     50.02
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           8.31e-14
# Time:                        21:59:41   Log-Likelihood:                -666.34
# No. Observations:                  67   AIC:                             1339.
# Df Residuals:                      64   BIC:                             1345.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.231e+04   1429.785     50.571      0.000    6.94e+04    7.52e+04
# Acceptance -2.813e+04   2847.016     -9.882      0.000   -3.38e+04   -2.24e+04
# Alumni        -0.0072      0.008     -0.874      0.385      -0.024       0.009
# ==============================================================================
# Omnibus:                        2.948   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.229   Jarque-Bera (JB):                2.379
# Skew:                           0.457   Prob(JB):                        0.304
# Kurtosis:                       3.127   Cond. No.                     5.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#relationship between average salary and acceptance rate controlling alumni size 
#(empty alumni size replaced with zero)
result = sm.ols(formula="Salary ~ Acceptance + Alumni", 
                data=d).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.578
# Method:                 Least Squares   F-statistic:                     44.85
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           8.97e-13
# Time:                        22:08:13   Log-Likelihood:                -647.12
# No. Observations:                  65   AIC:                             1300.
# Df Residuals:                      62   BIC:                             1307.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.132e+04   1937.438     36.810      0.000    6.74e+04    7.52e+04
# Acceptance -2.753e+04   2986.422     -9.218      0.000   -3.35e+04   -2.16e+04
# Alumni         0.0061      0.019      0.314      0.754      -0.033       0.045
# ==============================================================================
# Omnibus:                        2.854   Durbin-Watson:                   1.428
# Prob(Omnibus):                  0.240   Jarque-Bera (JB):                2.294
# Skew:                           0.457   Prob(JB):                        0.318
# Kurtosis:                       3.115   Cond. No.                     3.52e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#relationship between average salary and acceptance rate controlling alumni size 
#(universities with empty alumni size dropped)
result = sm.ols(formula="Salary ~ Acceptance + Alumni", 
                data=dd).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.578
# Method:                 Least Squares   F-statistic:                     44.85
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           8.97e-13
# Time:                        22:09:17   Log-Likelihood:                -647.12
# No. Observations:                  65   AIC:                             1300.
# Df Residuals:                      62   BIC:                             1307.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.132e+04   1937.438     36.810      0.000    6.74e+04    7.52e+04
# Acceptance -2.753e+04   2986.422     -9.218      0.000   -3.35e+04   -2.16e+04
# Alumni         0.0061      0.019      0.314      0.754      -0.033       0.045
# ==============================================================================
# Omnibus:                        2.854   Durbin-Watson:                   1.428
# Prob(Omnibus):                  0.240   Jarque-Bera (JB):                2.294
# Skew:                           0.457   Prob(JB):                        0.318
# Kurtosis:                       3.115   Cond. No.                     3.52e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'School_x', 'business_school', 'Acceptance', 'Salary',
#        'Private', 'Reputation', 'Alumni', 'Tuition', 'Distance', 'Far'],
#       dtype='object')

# %%
#relationship between average salary and acceptance rate controlling all variables
result = sm.ols(formula="Salary ~ Acceptance + Private + Reputation + Alumni + Tuition + Distance + Far", 
                data=data).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     15.84
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           1.58e-09
# Time:                        21:59:51   Log-Likelihood:                -442.66
# No. Observations:                  46   AIC:                             901.3
# Df Residuals:                      38   BIC:                             915.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.489e+04   9220.704      4.868      0.000    2.62e+04    6.36e+04
# Far[T.Far]   479.6163   1815.760      0.264      0.793   -3196.198    4155.430
# Acceptance -1.673e+04   4458.073     -3.753      0.001   -2.58e+04   -7705.937
# Private     2277.7891   2054.347      1.109      0.274   -1881.018    6436.596
# Reputation  5802.7446   1940.645      2.990      0.005    1874.114    9731.375
# Alumni        -0.0057      0.013     -0.437      0.665      -0.032       0.021
# Tuition        0.0450      0.071      0.631      0.532      -0.100       0.190
# Distance     -15.1456      9.992     -1.516      0.138     -35.373       5.081
# ==============================================================================
# Omnibus:                        0.036   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.982   Jarque-Bera (JB):                0.154
# Skew:                           0.060   Prob(JB):                        0.926
# Kurtosis:                       2.743   Cond. No.                     1.47e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#relationship between average salary and acceptance rate controlling all variables
#(empty alumni size replaced with zero)
result = sm.ols(formula="Salary ~ Acceptance + Private + Reputation + Alumni + Tuition + Distance + Far", 
                data=d).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     14.20
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           8.69e-09
# Time:                        22:00:03   Log-Likelihood:                -433.24
# No. Observations:                  45   AIC:                             882.5
# Df Residuals:                      37   BIC:                             896.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.368e+04   9447.890      4.624      0.000    2.45e+04    6.28e+04
# Far[T.Far]   748.7175   1869.827      0.400      0.691   -3039.913    4537.348
# Acceptance -1.632e+04   4528.858     -3.604      0.001   -2.55e+04   -7143.426
# Private     2278.1665   2068.729      1.101      0.278   -1913.476    6469.809
# Reputation  5903.3292   1959.691      3.012      0.005    1932.619    9874.039
# Alumni         0.0035      0.019      0.190      0.850      -0.034       0.041
# Tuition        0.0459      0.072      0.638      0.527      -0.100       0.192
# Distance     -14.9261     10.067     -1.483      0.147     -35.323       5.471
# ==============================================================================
# Omnibus:                        0.114   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.945   Jarque-Bera (JB):                0.230
# Skew:                           0.109   Prob(JB):                        0.891
# Kurtosis:                       2.726   Cond. No.                     1.31e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#relationship between average salary and acceptance rate controlling all variables
#(universities with empty alumni size dropped)
result = sm.ols(formula="Salary ~ Acceptance + Private + Reputation + Alumni + Tuition + Distance + Far", 
                data=d).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     14.20
# Date:                Mon, 29 Nov 2021   Prob (F-statistic):           8.69e-09
# Time:                        22:10:12   Log-Likelihood:                -433.24
# No. Observations:                  45   AIC:                             882.5
# Df Residuals:                      37   BIC:                             896.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.368e+04   9447.890      4.624      0.000    2.45e+04    6.28e+04
# Far[T.Far]   748.7175   1869.827      0.400      0.691   -3039.913    4537.348
# Acceptance -1.632e+04   4528.858     -3.604      0.001   -2.55e+04   -7143.426
# Private     2278.1665   2068.729      1.101      0.278   -1913.476    6469.809
# Reputation  5903.3292   1959.691      3.012      0.005    1932.619    9874.039
# Alumni         0.0035      0.019      0.190      0.850      -0.034       0.041
# Tuition        0.0459      0.072      0.638      0.527      -0.100       0.192
# Distance     -14.9261     10.067     -1.483      0.147     -35.323       5.471
# ==============================================================================
# Omnibus:                        0.114   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.945   Jarque-Bera (JB):                0.230
# Skew:                           0.109   Prob(JB):                        0.891
# Kurtosis:                       2.726   Cond. No.                     1.31e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
